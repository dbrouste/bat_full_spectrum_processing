# %% [markdown]
# # Bat chirp annotation
# Run this notebook from the repository root, or add the repository root to `sys.path`.

# %%
# %load_ext autoreload
# %autoreload 2

from annotation import run_annotator

# %%
WAV_FOLDER = r"D:\\Bat\\WAV"
ANNOTATIONS_FILE = r"D:\\Bat\\bat_chirp_annotations.json"

# %%
app = run_annotator(
    folder=WAV_FOLDER,
    annotations=ANNOTATIONS_FILE,
    fmin_khz=20,
    fmax_khz=180,
    db_floor=-90,
    jupyter_mode="external",
)
