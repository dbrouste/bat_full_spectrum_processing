# %% [markdown]
# # Bat chirp annotation
#
# Install the project once in editable mode from an Anaconda Prompt opened at the repository root:
#
# `python -m pip install -e .`
#
# After that, this notebook can import the packages from any working directory.

# %%
# %load_ext autoreload
# %autoreload 2

from annotation import run_annotator_dialog

# %% [markdown]
# ## Launch the annotator
#
# A native Windows dialog will ask you to select the folder containing the WAV files. WAV files are then searched recursively in all subfolders. The annotation JSON is saved automatically in the selected root folder as `bat_chirp_annotations.json`.
#
# For the current test set, select `D:\Bat recording\test\_annotation`.

# %%
app = run_annotator_dialog(
    initial_dir=r"D:\\Bat recording\\test\\_annotation",
    fmin_khz=20,
    fmax_khz=180,
    nperseg=1024,
    noverlap=896,
    db_floor=-90,
    seed=12345,
    jupyter_mode="external",
)
